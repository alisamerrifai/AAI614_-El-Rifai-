# %% [markdown]
# <a href="https://colab.research.google.com/github/alisamerrifai/AAI614_-El-Rifai-/blob/main/testing_github_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# This notebook is just implemented for testing purposes

# %%
# ex1
x = int(input("Enter a number please: "))

if x%2 == 0:
  print("The number is even")
else:
  print("The number is odd")
# Out:
# Enter a number please: 2
# The number is even
